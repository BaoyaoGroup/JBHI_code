# %%
import torch
from qgd_net import Model

# %%
net = Model(n_channels=4, n_classes=2, bilinear=False, num_groups=4)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
net = net.to(device)

# %%
model_path = "/home/zhrdai/projects/Pytorch-UNet/checkpoints/qgd_net/isic2017/num_groups_4/isic2017/checkpoint_epoch15.pth"

# %%
state_dict = torch.load(model_path, map_location=device)

# %%
mask_values = state_dict.pop("mask_values", [0, 1])
net.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
sum(p.numel() for p in net.parameters())
# Out:
# 105218
